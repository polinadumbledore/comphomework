# %% [markdown]
# Датасет IMDB Dataset Split из kaggle - https://www.kaggle.com/datasets/ducanger/imdb-dataset?resource=download&select=test.csv

# %% [markdown]
# Я невнимательно прочитала задание и заметила это, когда было поздно... вместо того, чтобы смотреть, каких слов в отзыве больше - из положительного списка или из отрицательного, сделала логистической регрессией. Но в конце все равно есть деление на эти списки, я просто не успела доделать это тем способом, которым надо было

# %%
from nltk.tokenize import wordpunct_tokenize
from pymorphy2 import MorphAnalyzer
import pandas as pd

# %%
morph = MorphAnalyzer()

# %%
from collections import Counter

# %%
from sklearn.feature_extraction.text import CountVectorizer
import nltk
from nltk.stem import WordNetLemmatizer 
lemmatizer = WordNetLemmatizer()

# %%
def lemmatize(inputfile):
    inputtext = []
    for text in inputfile:
        word_list = nltk.word_tokenize(text)
        lemmatized_output = ' '.join([lemmatizer.lemmatize(w) for w in word_list])
        inputtext.append(lemmatized_output)
    return inputtext

# %%
train = pd.read_csv("train.csv") 
test = pd.read_csv("test.csv") # прочитала файлы
lemma_test = lemmatize(test['review'])
lemma_train = lemmatize(train['review']) #лемматизировала файлы

# %%
cvec = CountVectorizer(binary=True, max_features=10000) 
cvec.fit(lemma_train)

X_train = cvec.transform(lemma_train).astype(int)
X_test = cvec.transform(lemma_test).astype(int)

# %%
feature_names = cvec.get_feature_names()

# %%
# использую логиситическую регрессию
from sklearn.linear_model import LogisticRegression

y_train = [bool(i) for i in train["sentiment"]] # завожу переменную для ответов, где True = полож,, False = отриц. отзыв

# %%
model = LogisticRegression()

model.fit(X_train, y_train) # завожу модель, обучаю
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score, f1_score # загружаю метрики

# %%
y_pred = model.predict(X_test) # предсказываю ответ
y_test = [bool(i) for i in test["sentiment"]]

# %%
pred_list = y_pred.tolist() # делаю из array список
true_pred_list = [] 
for prediction in pred_list:
    if prediction == True:
        true_pred_list.append(1)
    if prediction == False:
        true_pred_list.append(0) # меняю True и False на 1 и 0 соответственно
result = test[["review"]].copy()
result["sentiment"] = true_pred_list 
result.to_csv("resultnew.csv", index=False) # создаю csv табличку с результатами

# %%
from sklearn.metrics import accuracy_score, f1_score
accuracy_score(y_test, y_pred)
# Out:
# 0.8711

# %%
import csv 

df = pd.read_csv("train.csv", sep=",")
df =df.head(1000)

dictrev = pd.Series(df.sentiment.values,index=df.review).to_dict() #сделала из csv dict
posrev = []
negrev = []
for key, value in dictrev.items(): #добавляю все положительные отзывы в один список, все отрицательные - в другой
    if value == 1:
        posrev.append(key)
    if value == 0:
        negrev.append(key)
posrev = " ".join(posrev)
negrev = " ".join(negrev)

# %%
tokenized_posrev = nltk.word_tokenize(posrev)
tokenized_negrev = nltk.word_tokenize(negrev) #токенизирую  отзывы
onlypos = []
onlyneg = []
for word in tokenized_posrev: # делаю списки, где только те слова, которых нет в другом списке
    if word not in tokenized_negrev:
        onlypos.append(word)
for word in tokenized_negrev:
    if word not in tokenized_posrev:
        onlyneg.append(word)

# %%
posunigrams = Counter(onlypos)
negunigrams = Counter(onlyneg)
print(posunigrams)
print(negunigrams)
# Out:
# Counter({'Marie': 15, 'frog': 15, 'Bourne': 15, 'Oliver': 14, 'Dentist': 14, 'Hartley': 13, 'lily': 13, 'Sinatra': 12, 'Bud': 11, '10/10': 11, 'must-see': 10, 'Anne': 10, 'Feinstone': 10, 'mode': 10, 'Charlie': 10, 'Titta': 10, 'Ultimatum': 10, 'Floraine': 10, 'Yokai': 9, 'Kubrick': 9, 'Widmark': 9, '8/10': 9, 'Murphy': 9, 'Northfork': 9, 'Lumumba': 9, 'Fassbinder': 9, 'Master': 8, 'reveals': 8, 'format': 8, 'chess': 8, 'Loretta': 8, 'mobsters': 8, 'dentist': 8, 'Bernsen': 8, 'Old': 8, 'Michele': 8, 'Sky': 7, 'Homer': 7, 'Hamlet': 7, 'Page': 7, 'Julia': 7, 'initial': 7, 'strength': 7, 'Hal': 7, 'decades': 7, 'Ray': 7, 'Edgar': 7, 'exceptional': 7, 'stunts': 7, 'Wong': 7, 'Yuzna': 7, 'Tipping': 7, 'Simon': 7, 'Fiennes': 7, 'Atomic': 7, 'refreshing': 7, '\x91The': 7, 'Wai': 7, 'Milligan': 7, 'ANCHORS': 7, 'AWEIGH': 7, 'imagined': 6, 'Jake': 6, 'Rita': 6, 'Berlin': 6, 'Cole': 6, 'Fanning': 6, 'glimpse': 6, 'underrated': 6, 'flawless': 6, 'HBO': 6, 'Ronny': 6, 'Cowboy': 6, 'gripping': 6, 'ease': 6, 'overlooked': 6, 'Brooklyn': 6, 'millionaire': 6, 'Vincenzo': 6, 'Paxton': 6, 'understated': 6, 'wide': 6, 'artists': 6, 'Muppet': 6, 'Polish': 6, 'GoldenEye': 6, 'gamer': 6, 'sophisticated': 6, 'Ming': 6, 'chases': 6, 'haunting': 6, 'Felix': 6, '9/10': 6, 'EON': 6, 'Crowe': 6, 'Supremacy': 6, 'Kar': 6, "'Puckoon": 6, 'Raquel': 6, '-and': 6, 'Klaang': 6, 'Batwoman': 6, 'chainsaw': 5, 'reverence': 5, 'fairy': 5, 'tales': 5, 'Dance': 5, 'Irving': 5, 'Powell': 5, 'inventive': 5, 'integral': 5, 'Lisa': 5, 'innocence': 5, 'Spinal': 5, 'Cassidy': 5, 'celebration': 5, 'Cox': 5, 'Sweeney': 5, 'Pitt': 5, 'Juliette': 5, 'proved': 5, 'Venice': 5, 'Liu': 5, 'storm': 5, 'gift': 5, 'brilliantly': 5, 'Granger': 5, 'Jews': 5, 'timeless': 5, 'paranoia': 5, 'swimming': 5, 'JFK': 5, 'Series': 5, 'waiter': 5, 'hang': 5, 'Jacobi': 5, 'Corbin': 5, 'Brooke': 5, 'innovative': 5, 'Freedom': 5, 'X-Files': 5, 'Darren': 5, 'Highly': 5, 'Patient': 5, 'bathhouse': 5, 'education': 5, 'Samuel': 5, 'Ator': 5, 'lying': 5, 'Elvis': 5, "'Cliffhanger": 5, 'thieves': 5, 'Crossfire': 5, 'Runyon': 5, 'appreciated': 5, 'Lang': 5, 'Person': 5, 'Crazy': 5, 'Chow': 5, 'Russo': 5, 'Nikki': 5, 'TOWN': 5, 'Eglantine': 5, 'Brashear': 5, 'Tennison': 5, 'tag': 4, 'trials': 4, 'objects': 4, 'swept': 4, 'costume': 4, 'accessible': 4, 'delight': 4, 'Hayworth': 4, 'introduction': 4, 'coal': 4, 'friendly': 4, 'staff': 4, 'Krishna': 4, 'diamond': 4, 'Finch': 4, 'altered': 4, 'Institute': 4, 'ransom': 4, 'Denzel': 4, 'Mol': 4, 'captivating': 4, 'Peggy': 4, 'Tap': 4, '27': 4, 'learning': 4, 'Cheech': 4, 'continuing': 4, 'Spielberg': 4, 'versus': 4, 'Yang': 4, 'catchy': 4, 'strict': 4, 'Voight': 4, 'seldom': 4, 'candidate': 4, 'rewarded': 4, 'one-liners': 4, 'weakness': 4, 'stylish': 4, 'Cylons': 4, 'surprises': 4, 'feel-good': 4, 'Oscars': 4, 'Vera-Ellen': 4, 'Prot': 4, 'Midnight': 4, 'orphan': 4, 'seeks': 4, 'Strangers': 4, 'dinner': 4, 'Shylock': 4, 'hound': 4, 'cats': 4, 'sung': 4, 'Muppets': 4, 'light-hearted': 4, 'distant': 4, 'phase': 4, 'Daniels': 4, 'subsequent': 4, 'coolest': 4, 'Sean': 4, 'appreciation': 4, 'yrs': 4, 'Deathtrap': 4, 'Reeve': 4, 'perfection': 4, 'Scrooge': 4, 'Che': 4, 'fright': 4, 'tech': 4, 'Carlucci': 4, 'Secretary': 4, 'courage': 4, 'Novak': 4, 'answers': 4, 'decay': 4, 'affairs': 4, 'incest': 4, 'Indians': 4, 'Mitchum': 4, 'varied': 4, 'Biko': 4, 'Pilger': 4, 'bust': 4, 'Han': 4, 'Holden': 4, 'Gulfax': 4, 'clone': 4, 'dare': 4, 'Cold': 4, 'promise': 4, 'Sera': 4, 'Luzhin': 4, 'polished': 4, 'guide': 4, 'roller-coaster': 4, 'Zellweger': 4, 'Kidman': 4, 'backgrounds': 4, 'bartender': 4, 'Magnani': 4, 'L': 4, 'difficulty': 4, 'BLOB': 4, 'KOQs': 4, 'Cypher': 4, 'Nights': 4, 'definite': 4, 'embrace': 4, 'FULL': 4, 'RIDE': 4, 'sports': 4, 'well-acted': 4, 'FRWL': 4, 'Enjoy': 4, 'Hurt': 4, 'Verhoeven': 4, 'Assignment': 4, 'definition': 4, 'ill-fated': 4, 'Ritter': 4, 'Volckman': 4, 'creates': 4, 'Click': 4, 'Coppola': 4, 'soccer': 4, 'Britney': 4, 'Kaakha': 4, 'Sigourne ...
# Counter({'trivialBoring': 26, 'Norris': 20, 'laughable': 16, 'pathetic': 13, 'Sybok': 13, 'Avoid': 11, 'redeeming': 11, 'Reno': 11, 'Predator': 10, 'Cristina': 10, 'Domino': 10, 'contestant': 9, 'Sara': 9, 'ruined': 9, 'Halloween': 9, 'Burns': 9, 'Rambo': 9, 'Stars': 9, 'UK': 8, 'gon': 8, 'throw': 8, 'Shatner': 8, 'escapes': 8, 'wing': 8, 'substance': 8, '4/10': 8, 'non-existent': 8, 'messed': 8, 'Lugosi': 8, 'naked': 8, 'dropped': 8, 'Wrestlemania': 8, 'throat': 7, 'meaningless': 7, 'lousy': 7, 'porno': 7, 'Chuck': 7, 'Calvin': 7, 'miscast': 7, 'yeah': 7, 'deaths': 7, 'size': 7, 'Imagine': 7, 'sloppy': 7, 'Stupid': 7, 'Frost': 7, 'saves': 7, 'Could': 7, 'device': 7, 'enters': 7, 'scream': 7, 'Evan': 7, 'Lutz': 7, 'Rumble': 7, 'landing': 7, 'Bon': 7, 'Jovi': 7, 'Irwin': 7, 'Lassie': 7, 'Aliens': 6, '1st': 6, 'Marines': 6, 'unintentionally': 6, '1/10': 6, 'Shatter': 6, 'Freddy': 6, 'Austen': 6, 'Zombi': 6, 'Kenny': 6, 'General': 6, "N'T": 6, 'dollar': 6, 'entity': 6, 'cruel': 6, 'horrid': 6, 'Valentine': 6, 'string': 6, 'Freeman': 6, 'Bart': 6, 'THAT': 6, 'ranch': 6, 'stinks': 6, 'gross': 6, 'Horrible': 6, 'Cabin': 6, 'rushed': 6, 'logic': 6, 'Wagner': 6, 'cameras': 6, 'Vacation': 6, 'dubbing': 6, 'shake': 6, 'Witchcraft': 6, 'WITH': 6, 'Air': 6, 'Owen': 6, 'Arly': 6, 'yadda': 6, 'tank': 6, 'homeless': 6, 'Hogan': 6, 'closets': 6, 'Frederick': 6, 'Andre': 6, 'Odin': 6, 'Blair': 5, 'cringe': 5, 'atrocious': 5, 'Perry': 5, 'crappy': 5, 'Prosatano': 5, 'Israel': 5, 'Israeli': 5, 'Christianity': 5, 'MST3K': 5, 'superman': 5, 'superhero': 5, 'fathom': 5, 'E': 5, 'moronic': 5, 'prom': 5, '2/10': 5, 'Grudge': 5, 'flesh': 5, 'lifeless': 5, 'jumped': 5, 'IT': 5, 'influenced': 5, 'Minchin': 5, 'curse': 5, 'whiny': 5, 'hick': 5, 'loser': 5, 'Woody': 5, 'charisma': 5, 'preposterous': 5, 'deserve': 5, 'Ritchie': 5, 'countries': 5, 'Savannah': 5, 'frequently': 5, 'Smile': 5, '3/10': 5, 'Clearly': 5, 'Kayako': 5, '1000': 5, 'Masters': 5, 'pops': 5, 'tiny': 5, 'stand-up': 5, 'Acting': 5, 'Chopper': 5, 'crashes': 5, 'Universal': 5, 'high-rise': 5, 'investigating': 5, 'TFTC': 5, 'MOH': 5, 'Reeves': 5, 'hype': 5, 'resolution': 5, 'category': 5, 'Hornblower': 5, 'evidently': 5, 'beard': 5, 'tasteless': 5, 'Svankmajer': 5, 'rubbish': 5, 'inject': 5, '180': 5, 'sub-par': 5, 'flesh-eating': 5, 'Cortez': 5, 'Louque': 5, 'Factor': 5, 'Suit': 5, 'spending': 5, 'agony': 5, 'norwegian': 5, 'removed': 5, 'tickets': 5, 'commander': 5, 'Seaview': 5, 'Burke': 5, 'doors': 5, 'Vs': 5, 'Ventura': 5, 'Edison': 5, 'Chaplin': 5, 'avoided': 4, 'Greek': 4, 'AVP': 4, 'screenwriter': 4, 'Burr': 4, 'dimensional': 4, 'motives': 4, 'Down': 4, 'countless': 4, 'pile': 4, 'nail': 4, 'Bezi': 4, 'disliked': 4, 'slugs': 4, 'depressive': 4, 'Singer': 4, '22': 4, 'Guess': 4, 'besides': 4, 'wannabe': 4, 'ass': 4, 'proof': 4, 'readily': 4, 'Blank': 4, 'Pang': 4, 'relies': 4, 'undead': 4, 'Mattei': 4, 'rifles': 4, 'unintentional': 4, 'insulting': 4, 'ridiculously': 4, 'lesbian': 4, 'turkey': 4, 'nonsensical': 4, 'padding': 4, 'fitting': 4, 'NEVER': 4, 'endure': 4, 'disgusted': 4, 'nuts': 4, 'scarier': 4, 'staring': 4, 'acting.': 4, 'Skip': 4, 'shark': 4, 'designed': 4, '18': 4, 'Hoskins': 4, 'claimed': 4, 'moron': 4, 'Haack': 4, 'electronic': 4, 'ideology': 4, 'wacky': 4, "'S": 4, 'Greenwood': 4, 'classes': 4, 'ad': 4, '35': 4, 'Tenchi': 4, 'tad': 4, 'travesty': 4, 'spider': 4, 'cave': 4, 'puppets': 4, 'unwatchable': 4, 'Huh': 4, 'Bennett': 4, 'TO': 4, 'Indeed': 4, 'Using': 4, 'indication': 4, 'emergency': 4, 'robot': 4, 'Claus': 4, 'implausible': 4, 'Bela': 4, 'Rukh': 4, 'wins': 4, 'slack': 4, 'hack': 4, 'J.': 4, 'queen': 4, '0': 4, 'channels': 4, 'Sarandon': 4, 'rooms': 4, 'Killjoy': 4, 'downright': 4, 'Nobody': 4, 'Choco': 4, 'Downey': 4, 'resort': 4, 'Grandma': 4, 'stated': 4, 'clichéd': 4, 'campfire': 4, 'WWE': 4, 'Boring': 4, 'Nana': 4, 'Renoir': 4, 'mustache': 4, 'handed': 4, 'worried': 4, 'skirts': 4, 'overlook': 4, 'Alois': 4, 'correctly': 4, 'possibilities': 4, 'Worse': 4, ...
